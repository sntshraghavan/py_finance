# %%
import datetime as dt
import matplotlib.pyplot as plt
from matplotlib import style
import pandas as pd
import pandas_datareader.data as web
import urllib as u
import urllib.request
from bs4 import BeautifulSoup as bs
import datetime as dt
import numpy as np
import os
import pickle
import requests
import yfinance as yf

# %%
def get_price2book( symbol ):
    try:
        url = r'http://finviz.com/quote.ashx?t={}'\
        				.format(symbol.lower())
        html = u.request.urlopen(url).read()
        soup = bs(html, 'lxml')
        # Change the text below to get a diff metric
        pb =  soup.find(text = r'P/B')
        pb_ = pb.find_next(class_='snapshot-td2').text
        roe =  soup.find(text = r'ROE')
        roe_ = roe.find_next(class_='snapshot-td2').text
        mc =  soup.find(text = r'Market Cap')
        mc_ = mc.find_next(class_='snapshot-td2').text
        de =  soup.find(text = r'Debt/Eq')
        de_ = de.find_next(class_='snapshot-td2').text
        dp =  soup.find(text = r'Dividend %')
        dp_ = dp.find_next(class_='snapshot-td2').text
        #print( '{} price to book = {} '.format(symbol, pb_) )
        #print( '{} roe = {} '.format(symbol, roe_) )
        return (pb_,roe_,mc_,de_,dp_)
    except Exception as e:
        print(e)

# %%
style.use('ggplot')


def save_sp500_tickers():
    resp = requests.get('http://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
    soup = bs(resp.text, 'lxml')
    table = soup.find('table', {'class': 'wikitable sortable'})
    tickers = []
    for row in table.findAll('tr')[1:]:
        ticker = row.findAll('td')[0].text
        tickers.append(ticker)
    with open("sp500tickers.pickle", "wb") as f:
        pickle.dump(tickers, f)
    return tickers


#save_sp500_tickers()

# %%
def get_data_from_yahoo(reload_sp500=False):
    if reload_sp500:
        tickers = save_sp500_tickers()
    else:
        with open("sp500tickers.pickle", "rb") as f:
            tickers = pickle.load(f)
    if not os.path.exists('stock_dfs'):
        os.makedirs('stock_dfs')

    start = dt.datetime(2010, 1, 1)
    end = dt.datetime.now()
    for ticker in tickers:
        print(ticker.rstrip())
        print(format(ticker))
        # just in case your connection breaks, we'd like to save our progress!
        if not os.path.exists('stock_dfs/{}.csv'.format(ticker.splitlines()[0])):
            df = yf.download(ticker, start, end)
            #df.reindex(columns=cols)
            df.reset_index(inplace=True)
            df.set_index("Date", inplace=True)
            df = df.drop("Adj Close", axis=1)
            print(df)
            df.to_csv('stock_dfs/{}.csv'.format(ticker.splitlines()[0]))
        else:
            print('Already have {}'.format(ticker.splitlines()[0]))

#get_data_from_yahoo()
            
def compile_data():
    with open("sp500tickers.pickle", "rb") as f:
        tickers = pickle.load(f)

    main_df = pd.DataFrame()

    for count, ticker in enumerate(tickers):
        df = pd.read_csv('stock_dfs/{}.csv'.format(ticker.splitlines()[0]))
        df.set_index('Date', inplace=True)

        df.rename(columns={'Adj Close': ticker}, inplace=True)
        df.drop(['Open', 'High', 'Low', 'Close', 'Volume'], 1, inplace=True)

        if main_df.empty:
            main_df = df
        else:
            main_df = main_df.join(df, how='outer')

        if count % 10 == 0:
            print(count)
    print(main_df.head())
    main_df.to_csv('sp500_joined_closes.csv')


def visualize_data():
    df = pd.read_csv('sp500_joined_closes.csv')
    df_corr = df.corr()
    print(df_corr.head())
    df_corr.to_csv('sp500corr.csv')
    data1 = df_corr.values
    fig1 = plt.figure()
    ax1 = fig1.add_subplot(111)

    heatmap1 = ax1.pcolor(data1, cmap=plt.cm.RdYlGn)
    fig1.colorbar(heatmap1)

    ax1.set_xticks(np.arange(data1.shape[1]) + 0.5, minor=False)
    ax1.set_yticks(np.arange(data1.shape[0]) + 0.5, minor=False)
    ax1.invert_yaxis()
    ax1.xaxis.tick_top()
    column_labels = df_corr.columns
    row_labels = df_corr.index
    ax1.set_xticklabels(column_labels)
    ax1.set_yticklabels(row_labels)
    plt.xticks(rotation=90)
    heatmap1.set_clim(-1, 1)
    plt.tight_layout()
    plt.show()



#visualize_data()

# %%
def analyse_data_from_yahoo():
    with open("sp500tickers.pickle", "rb") as f:
        tickers = pickle.load(f)
    analysis = pd.DataFrame(columns=['drop ratio','pb','roe','market cap','price on 04-09','Debt/Eq','Dividend %'])
    
    i=0
    for ticker in tickers:
        i=i+1
        #print(ticker.splitlines()[0])
        #print(df.shape)
        ticker = ticker[:-1]
        if os.path.exists('stock_dfs/{}.csv'.format(ticker)):
            df = pd.read_csv('stock_dfs/{}.csv'.format(ticker), parse_dates=True, index_col=0)
            print(ticker,df.shape,df.shape[0] )
            df['10ma']=(df['Close'].rolling(window=10, min_periods=0).mean())
            #print(df['10ma'])
            #analysis.loc[i] =  [ticker  ,  df['10ma'].iloc[320]/df['10ma'].iloc[1] ]
            #analysis[ticker]  = [  df['10ma'].iloc[320]/df['10ma'].iloc[1] ]
            if df.shape[0]==2587:
                analysis.loc[ticker,'drop ratio']  = df.loc['2020-04-09','10ma']/df.loc['2020-01-06','10ma'] 
                analysis.loc[ticker,'price on 04-09']  =  df.loc['2020-04-09','Close'] 
            print(ticker,i)
            try:
                temp= get_price2book(ticker)    
                analysis.loc[ticker,'pb']  = temp[0]
                analysis.loc[ticker,'roe']  = temp[1]
                analysis.loc[ticker,'market cap']  = temp[2]
                analysis.loc[ticker,'Debt/Eq']  = temp[3]
                analysis.loc[ticker,'Dividend %']  = temp[4]
                print(analysis.loc[ticker])
            except:
                print("An exception occurred")
        else:
            print('Already have {}'.format(ticker))
    
    analysis.to_csv("500_analysis.csv")

# %%
analyse_data_from_yahoo()
# Out:
# MMM (2587, 5) 2587
# MMM 1
# drop ratio        0.786158
# pb                    8.60
# roe                 45.10%
# market cap          87.08B
# price on 04-09      147.78
# Debt/Eq               2.03
# Dividend %           3.92%
# Name: MMM, dtype: object
# ABT (2587, 5) 2587
# ABT 2
# drop ratio        0.925312
# pb                    5.07
# roe                 11.70%
# market cap         157.60B
# price on 04-09       86.04
# Debt/Eq               0.58
# Dividend %           1.62%
# Name: ABT, dtype: object
# ABBV (1833, 5) 1833
# ABBV 3
# drop ratio            NaN
# pb                      -
# roe               -95.60%
# market cap        121.88B
# price on 04-09        NaN
# Debt/Eq                 -
# Dividend %          5.75%
# Name: ABBV, dtype: object
# ABMD (2587, 5) 2587
# ABMD 4
# drop ratio        0.876052
# pb                    6.96
# roe                 24.70%
# market cap           7.28B
# price on 04-09      160.08
# Debt/Eq               0.00
# Dividend %               -
# Name: ABMD, dtype: object
# ACN (2588, 5) 2588
# ACN 5
# drop ratio            NaN
# pb                   7.34
# roe                33.80%
# market cap        113.77B
# price on 04-09        NaN
# Debt/Eq              0.00
# Dividend %          1.80%
# Name: ACN, dtype: object
# ATVI (2587, 5) 2587
# ATVI 6
# drop ratio        1.00984
# pb                   3.81
# roe                12.40%
# market cap         49.17B
# price on 04-09      60.46
# Debt/Eq              0.21
# Dividend %          0.65%
# Name: ATVI, dtype: object
# ADBE (2587, 5) 2587
# ADBE 7
# drop ratio        0.939174
# pb                   15.70
# roe                 31.40%
# market cap         164.25B
# price on 04-09       318.7
# Debt/Eq               0.39
# Dividend %               -
# Name: ADBE, dtype: object
# AMD (2587, 5) 2587
# AMD 8
# drop ratio        0.992453
# pb                   22.15
# roe                 15.70%
# market cap          64.86B
# price on 04-09       48.38
# Debt/Eq               0.17
# Dividend %               -
# Name: AMD, dtype: object
# AAP (2587, 5) 2587
# AAP 9
# drop ratio        0.59847
# pb                   2.26
# roe                13.70%
# market cap          8.01B
# price on 04-09     106.86
# Debt/Eq              0.21
# Dividend %          0.87%
# Name: AAP, dtype: object
# AES (2587, 5) 2587
# AES 10
# drop ratio        0.67549
# pb                   3.12
# roe                 9.60%
# market cap          9.34B
# price on 04-09      14.72
# Debt/Eq              6.73
# Dividend %          4.07%
# Name: AES, dtype: object
# AFL (2587, 5) 2587
# AFL 11
# drop ratio        0.660044
# pb                    0.96
# roe                 11.70%
# market cap          27.07B
# price on 04-09       38.08
# Debt/Eq               0.22
# Dividend %           2.96%
# Name: AFL, dtype: object
# A (2587, 5) 2587
# A 12
# drop ratio        0.856918
# pb                    5.04
# roe                 15.70%
# market cap          24.44B
# price on 04-09       78.33
# Debt/Eq               0.51
# Dividend %           0.91%
# Name: A, dtype: object
# APD (2587, 5) 2587
# APD 13
# drop ratio        0.858608
# pb                    4.22
# roe                 16.70%
# market cap          48.77B
# price on 04-09      219.32
# Debt/Eq               0.29
# Dividend %           2.43%
# Name: APD, dtype: object
# AKAM (2587, 5) 2587
# AKAM 14
# drop ratio        1.0879
# pb                  4.44
# roe               13.80%
# market cap        16.61B
# price on 04-09     95.39
# Debt/Eq             0.50
# Dividend %             -
# Name: AKAM, dtype: object
# ALK (2587, 5) 2587
# ALK 15
# drop ratio        0.408707
# pb                    0.88
# roe                 18.90%
# market cap           3.82B
# price on 04-09       31.61
# Debt/Eq               0.35
# Dividend %               -
# Name: ALK, dtype: object
# ALB (2587, 5) 2587
# ALB 16
# drop ratio        0.792725
# pb                    1.72
# roe                 14.00%
# market cap           6.75B
# price on 04-09       67.02
# Debt/Eq               0.78
# Dividend %           2.42%
# Name: ALB, dtype: object
# ARE (2587, 5) 2587
# ARE 17
# drop ratio        0.873473
# pb                    2.00
# roe                  4.40%
# market cap          18.32B
# price on 04-09       157.8
# Debt/Eq               0.76
# Dividend %           2.65%
# Name: ARE, dtype: object
# ALXN (2587, 5) 2587
# ALXN 18
# drop ratio        0.845281
# pb                    1.95
# roe                 23.20%
# market cap          22.61B
# price on 04-09       96.23
# Debt/Eq               0.23
# Dividend %               -
# Name: ALXN, dtype: object
# ALGN (2587, 5) 2587
# ALGN 19
# drop ratio        0.617772
# pb                   11.09
# roe                 33.50%
# market cap          14.28B
# price on 04-09      193.19
# Debt/Eq               0.00
# Dividend %               -
# Name: ALGN, dtype: object
# ALLE (1611, 5) 1611
# ALLE 20
# drop ratio           NaN
# pb                 12.03
# roe               58.70%
# market cap         9.11B
# price on 04-09       NaN
# Debt/Eq             1.89
# Dividend %         1.31%
# Name: ALLE, dtype: object
# AGN (2588, 5) 2588
# AGN 21
# drop ratio           NaN
# pb                  1.05
# roe               -8.90%
# market cap        61.06B
# price on 04-09       NaN
# Debt/Eq             0.39
# Dividend %         1.59%
# Name: AGN, dtype: object
# ADS (2587, 5) 2587
# ADS 22
# drop ratio        0.302495
# pb                    1.07
# roe                 13.90%
# market cap           1.83B
# price on 04-09       38.58
# Debt/Eq              14.03
# Dividend %           6.92%
# Name: ADS, dtype: object
# LNT (2587, 5) 2587
# LNT 23
# drop ratio        0.892175
# pb                    2.48
# roe                 11.40%
# market cap          12.67B
# price on 04-09       53.14
# Debt/Eq               1.25
# Dividend %           2.83%
# Name: LNT, dtype: object
# ALL (2587, 5) 2587
# ALL 24
# drop ratio        0.818316
# pb                    1.38
# roe                 20.60%
# market cap          32.82B
# price on 04-09      100.34
# Debt/Eq               0.28
# Dividend %           2.11%
# Name: ALL, dtype: object
# GOOGL (2587, 5) 2587
# GOOGL 25
# drop ratio        0.848139
# pb                    4.33
# roe                 17.80%
# market cap         871.06B
# price on 04-09     1206.57
# Debt/Eq               0.00
# Dividend %               -
# Name: GOOGL, dtype: object
# GOOG (2587, 5) 2587
# GOOG 26
# drop ratio        0.851669
# pb                    4.34
# roe                      -
# market cap         864.24B
# price on 04-09     1211.45
# Debt/Eq                  -
# Dividend %               -
# Name: GOOG, dtype: object
# MO (2587, 5) 2587
# MO 27
# drop ratio        0.757879
# pb                   12.61
# roe                -11.50%
# market cap          78.47B
# price on 04-09       40.91
# Debt/Eq               4.51
# Dividend %           7.98%
# Name: MO, dtype: object
# AMZN (2587, 5) 2587
# AMZN 28
# drop ratio         1.06299
# pb                   18.25
# roe                 21.10%
# market cap        1136.80B
# price on 04-09     2042.76
# Debt/Eq               0.67
# Dividend %               -
# Name: AMZN, dtype: object
# AMCR (1991, 5) 1991
# AMCR 29
# drop ratio           NaN
# pb                  2.73
# roe                    -
# market cap        14.59B
# price on 04-09       NaN
# Debt/Eq             1.16
# Dividend %         5.09%
# Name: AMCR, dtype: object
# AEE (2587, 5) 2587
# AEE 30
# drop ratio        0.964125
# pb                    2.35
# roe                 10.50%
# market cap          18.98B
# price on 04-09          79
# Debt/Eq               1.22
# Dividend %           2.57%
# Name: AEE, dtype: object
# AAL (2587, 5) 2587
# AAL 31
# drop ratio        0.391321
# pb                       -
# roe                      -
# market cap           5.19B
# price on 04-09       12.51
# Debt/Eq                  -
# Dividend %           3.35%
# Name: AAL, dtype: object
# AEP (2587, 5) 2587
# AEP 32
# drop ratio        0.8492
# pb                  2.17
# roe                9.80%
# market cap        41.19B
# price on 04-09     86.31
# Debt/Eq             1.52
# Dividend %         3.25%
# Name: AEP, dtype: object
# AXP (2587, 5) 2587
# AXP 33
# drop ratio        0.681448
# pb                    3.11
# roe                 29.00%
# market cap          71.86B
# price on 04-09       94.82
# Debt/Eq               5.96
# Dividend %           1.95%
# Name: AXP, dtype: object
# AIG (2587, 5) 2587
# AIG 34
# drop ratio        0.457509
# pb                    0.35
# roe                  5.20%
# market cap          22.64B
# price on 04-09       26.54
# Debt/Eq               0.54
# Dividend %           4.97%
# Name: AIG, dtype: object
# AMT (2587, 5) 2587
# AMT 35
# drop ratio        1.00265
# pb                  22.36
# roe                35.80%
# market cap        113.00B
# price on 04-09      259.6
# Debt/Eq              4.76
# Dividend %          1.55%
# Name: AMT, dtype: object
# AWK (2587, 5) 2587
# AWK 36
# drop ratio        0.991218
# pb                    3.95
# roe                 10.20%
# market cap          24.18B
# price on 04-09      131.75
# Debt/Eq               1.55
# Dividend %           1.50%
# Name: AWK, dtype: object
# AMP (2587, 5) 2587
# AMP 37
# drop ratio        0.616349
# pb                    2.57
# roe                 32.10%
# market cap          14.74B
# price on 04-09      120.47
# Debt/Eq               3.38
# Dividend %           3.39%
# Name: AMP, dtype: object
# ABC (2587, 5) 2587
# ABC 38
# drop ratio        1.01157
# pb                   6.24
# roe                22.10%
# market cap         18.52B
# price on 04-09      87.81
# Debt/Eq              1.41
# Dividend %          1.88%
# Name: ABC, dtype: object
# AME (2587, 5) 2587
# AME 39
# drop ratio        0.734071
# pb                    3.49
# roe                 18.00%
# market cap          17.85B
# price on 04-09       78.23
# Debt/Eq               0.54
# Dividend %           0.92%
# Name: AME, dtype: object
# AMGN (2587, 5) 2587
# AMGN 40
# drop ratio        0.86206
# pb                  13.91
# roe                74.30%
# market cap        134.37B
# price on 04-09     218.21
# Debt/Eq              3.09
# Dividend %          2.82%
# Name: AMGN, dtype: object
# APH (2587, 5) 2587
# APH 41
# drop ratio        0.687883
# pb                    5.41
# roe                 27.20%
# market cap          24.51B
# price on 04-09       81.91
# Debt/Eq               0.80
# Dividend %           1.21%
# Name: APH, dtype: object
# ADI (2587, 5) 2587
# ADI 42
# drop ratio        0.772197
# pb                    3.25
# roe                      -
# market cap          38.94B
# price on 04-09       98.79
# Debt/Eq               0.47
# Dividend %           2.41%
# Name: ADI, dtype: object
# ANSS (2587, 5) 2587
# ANSS 43
# drop ratio        0.894031
# pb                    6.29
# roe                 15.20%
# market cap          22.40B
# price on 04-09      237.92
# Debt/Eq               0.14
# Dividend %               -
# Name: ANSS, dtype: object
# ANTM (2587, 5) 2587
# ANTM 44
# drop ratio        0.742822
# pb                    2.01
# roe                 15.50%
# market cap          64.74B
# price on 04-09      242.46
# Debt/Eq               0.63
# Dividend %           1.51%
# Name: ANTM, dtype: object
# AON (2587, 5) 2587
# AON 45
# drop ratio        0.814375
# pb                   13.49
# roe                 39.60%
# market cap          45.54B
# price on 04-09      192.05
# Debt/Eq               2.20
# Dividend %           0.91%
# Name: AON, dtype: object
# AOS (2588, 5) 2588
# AOS 46
# drop ratio           NaN
# pb                  3.98
# roe               21.80%
# market cap         6.59B
# price on 04-09       NaN
# Debt/Eq             0.17
# Dividend %         2.36%
# Name: AOS, dtype: object
# APA (2587, 5) 2587
# APA 47
# drop ratio        0.216877
# pb                    0.94
# roe                -61.50%
# market cap           3.05B
# price on 04-09         8.2
# Debt/Eq               2.63
# Dividend %           1.24%
# Name: APA, dtype: object
# AIV (2587, 5) 2587
# AIV 48
# drop ratio        0.676984
# pb                    3.29
# roe                 26.60%
# market cap           5.86B
# price on 04-09       39.97
# Debt/Eq               0.00
# Dividend %           4.15%
# Name: AIV, dtype: object
# AAPL (2587, 5) 2587
# AAPL 49
# drop ratio        0.872818
# pb                   14.15
# roe                 60.20%
# market cap        1267.34B
# price on 04-09      267.99
# Debt/Eq               1.22
# Dividend %           1.07%
# Name: AAPL, dtype: object
# AMAT (2588, 5) 2588
# AMAT 50
# drop ratio           NaN
# pb                  5.55
# roe               34.10%
# market cap        50.00B
# price on 04-09       NaN
# Debt/Eq             0.61
# Dividend %         1.68%
# Name: AMAT, dtype: object
# APTV (2113, 5) 2113
# APTV 51
# drop ratio           NaN
# pb                  4.20
# roe               27.70%
# market cap        16.04B
# price on 04-09       NaN
# Debt/Eq             1.14
# Dividend %             -
# Name: APTV, dtype: object
# ADM (2587, 5) 2587
# ADM 52
# drop ratio        0.766699
# pb                    1.09
# roe                  7.30%
# market cap          20.85B
# price on 04-09       37.58
# Debt/Eq               0.46
# Dividend %           3.87%
# Name: ADM, dtype: object
# ANET (1474, 5) 1474
# ANET 53
# drop ratio           NaN
# pb                  5.47
# roe               32.80%
# market cap        16.21B
# price on 04-09       NaN
# Debt/Eq             0.00
# Dividend %             -
# Name: ANET, dtype: object
# AJG (2587, 5) 2587
# AJG 54
# drop ratio        0.855879
# pb                    3.15
# roe                 13.50%
# market cap          16.07B
# price on 04-09       86.84
# Debt/Eq               0.89
# Dividend %           2.08%
# Name: AJG, dtype: object
# AIZ (2587, 5) 2587
# AIZ 55
# drop ratio        0.79873
# pb                   1.17
# roe                 6.50%
# market cap          6.59B
# price on 04-09     112.39
# Debt/Eq              0.36
# Dividend %          2.34%
# Name: AIZ, dtype: object
# T (2587, 5) 2587
# T 56
# drop ratio        0.75151
# pb                   1.24
# roe                 7.50%
# market cap        227.65B
# price on 04-09      30.73
# Debt/Eq              0.89
# Dividend %          6.68%
# Name: T, dtype: object
# ATO (2587, 5) 2587
# ATO 57
# drop ratio        0.897391
# pb                    2.14
# roe                      -
# market cap          13.09B
# price on 04-09       105.2
# Debt/Eq               0.71
# Dividend %           2.13%
# Name: ATO, dtype: object
# ADSK (2587, 5) 2587
# ADSK 58
# drop ratio        0.809329
# pb                       -
# roe               -114.40%
# market cap          37.89B
# price on 04-09       164.9
# Debt/Eq                  -
# Dividend %               -
# Name: ADSK, dtype: object
# ADP (2587, 5) 2587
# ADP 59
# drop ratio        0.794843
# pb                   11.57
# roe                 46.10%
# market cap          62.08B
# price on 04-09      142.52
# Debt/Eq               0.37
# Dividend %           2.53%
# Name: ADP, dtype: object
# AZO (2587, 5) 2587
# AZO 60
# drop ratio        0.714229
# pb                       -
# roe                -95.50%
# market cap          23.03B
# price on 04-09      940.83
# Debt/Eq                  -
# Dividend %               -
# Name: AZO, dtype: object
# AVB (2587, 5) 2587
# AVB 61
# drop ratio        0.713021
# pb                    2.12
# roe                  7.20%
# market cap          22.58B
# price on 04-09      167.36
# Debt/Eq               0.67
# Dividend %           3.81%
# Name: AVB, dtype: object
# AVY (2587, 5) 2587
# AVY 62
# drop ratio        0.780784
# pb                    7.65
# roe                 28.10%
# market cap           9.22B
# price on 04-09      115.03
# Debt/Eq               1.61
# Dividend %           2.10%
# Name: AVY, dtype: object
# BKR (2587, 5) 2587
# BKR 63
# drop ratio        0.446073
# pb                    0.25
# roe                  0.40%
# market cap          13.81B
# price on 04-09       12.86
# Debt/Eq               0.19
# Dividend %           5.39%
# Name: BKR, dtype: object
# BLL (2587, 5) 2587
# BLL 64
# drop ratio        1.01197
# pb                   7.52
# roe                17.00%
# market cap         22.17B
# price on 04-09      69.94
# Debt/Eq              2.65
# Dividend %          0.88%
# Name: BLL, dtype: object
# BAC (2587, 5) 2587
# BAC 65
# drop ratio        0.61674
# pb                   0.89
# roe                10.60%
# market cap        213.89B
# price on 04-09      24.86
# Debt/Eq              1.77
# Dividend %          3.03%
# Name: BAC, dtype: object
# BK (2587, 5) 2587
# BK 66
# drop ratio        0.680024
# pb                    0.87
# roe                 11.30%
# market cap          33.12B
# price on 04-09       37.14
# Debt/Eq               0.74
# Dividend %           3.41%
# Name: BK, dtype: object
# BAX (2587, 5) 2587
# BAX 67
# drop ratio        0.976878
# pb                    5.66
# roe                 13.00%
# market cap          44.65B
# price on 04-09       86.89
# Debt/Eq               0.68
# Dividend %           1.00%
# Name: BAX, dtype: object
# BDX (2587, 5) 2587
# BDX 68
# drop ratio        0.85561
# pb                   3.19
# roe                 3.60%
# market cap         68.36B
# price on 04-09     247.45
# Debt/Eq              0.92
# Dividend %          1.27%
# Name: BDX, dtype: object
# BRK.B (0, 5) 0
# BRK.B 69
# HTTP Error 404: Not Found
# An exception occurred
# BBY (2587, 5) 2587
# BBY 70
# drop ratio        0.675511
# pb                    5.25
# roe                 46.50%
# market cap          17.53B
# price on 04-09       65.99
# Debt/Eq               0.37
# Dividend %           3.15%
# Name: BBY, dtype: object
# BIIB (2587, 5) 2587
# BIIB 71
# drop ratio        1.03389
# pb                   4.45
# roe                43.50%
# market cap         59.34B
# price on 04-09     321.05
# Debt/Eq              0.45
# Dividend %              -
# Name: BIIB, dtype: object
# BLK (2587, 5) 2587
# BLK 72
# drop ratio        0.875349
# pb                    2.12
# roe                 13.90%
# market cap          71.08B
# price on 04-09      471.42
# Debt/Eq               0.15
# Dividend %           3.17%
# Name: BLK, dtype: object
# BA (2587, 5) 2587
# BA 73
# drop ratio        0.43224
# pb                      -
# roe                14.30%
# market cap         79.98B
# price on 04-09     151.84
# Debt/Eq                 -
# Dividend %              -
# Name: BA, dtype: object
# BKNG (2587, 5) 2587
# BKNG 74
# drop ratio        0.642764
# pb                   10.19
# roe                 80.70%
# market cap          60.45B
# price on 04-09     1420.64
# Debt/Eq               1.45
# Dividend %               -
# Name: BKNG, dtype: object
# BWA (2587, 5) 2587
# BWA 75
# drop ratio        0.550386
# pb                    1.19
# roe                 16.70%
# market cap           5.57B
# price on 04-09       25.74
# Debt/Eq               0.42
# Dividend %           2.50%
# Name: BWA, dtype: object
# BXP (2587, 5) 2587
# BXP 76
# drop ratio        0.672628
# pb                    2.98
# roe                  9.20%
# market cap          15.47B
# price on 04-09         106
# Debt/Eq               2.19
# Dividend %           3.71%
# Name: BXP, dtype: object
# BSX (2587, 5) 2587
# BSX 77
# drop ratio        0.720442
# pb                    3.61
# roe                 44.50%
# market cap          47.94B
# price on 04-09       36.83
# Debt/Eq               0.72
# Dividend %               -
# Name: BSX, dtype: object
# BMY (2587, 5) 2587
# BMY 78
# drop ratio        0.882535
# pb                    2.23
# roe                 13.70%
# market cap         134.32B
# price on 04-09       58.91
# Debt/Eq               0.91
# Dividend %           3.00%
# Name: BMY, dtype: object
# AVGO (2587, 5) 2587
# AVGO 79
# drop ratio        0.763856
# pb                    4.37
# roe                 10.90%
# market cap         109.86B
# price on 04-09       254.3
# Debt/Eq               1.84
# Dividend %           3.96%
# Name: AVGO, dtype: object
# BR (2587, 5) 2587
# BR 80
# drop ratio        0.783028
# pb                   10.90
# roe                 36.20%
# market cap          12.27B
# price on 04-09      105.91
# Debt/Eq               1.64
# Dividend %           2.02%
# Name: BR, dtype: object
# BF.B (0, 5) 0
# BF.B 81
# HTTP Error 404: Not Found
# An exception occurred
# CHRW (2587, 5) 2587
# CHRW 82
# drop ratio        0.887714
# pb                    5.78
# roe                 34.70%
# market cap           9.27B
# price on 04-09       73.22
# Debt/Eq               0.79
# Dividend %           2.87%
# Name: CHRW, dtype: object
# COG (2587, 5) 2587
# COG 83
# drop ratio        1.01643
# pb                   3.67
# roe                30.20%
# market cap          7.92B
# price on 04-09      18.88
# Debt/Eq              0.57
# Dividend %          2.05%
# Name: COG, dtype: object
# CDNS (2587, 5) 2587
# CDNS 84
# drop ratio        0.957296
# pb                    9.93
# roe                 62.00%
# market cap          21.49B
# price on 04-09       71.65
# Debt/Eq               0.16
# Dividend %               -
# Name: CDNS, dtype: object
# CPB (2587, 5) 2587
# CPB 85
# drop ratio        0.955131
# pb                    6.06
# roe                 95.60%
# market cap          14.61B
# price on 04-09       47.75
# Debt/Eq               2.33
# Dividend %           2.80%
# Name: CPB, dtype: object
# COF (2587, 5) 2587
# COF 86
# drop ratio        0.495763
# pb                    0.48
# roe                 10.10%
# market cap          25.50B
# price on 04-09       60.11
# Debt/Eq               0.91
# Dividend %           2.89%
# Name: COF, dtype: object
# CPRI (2094, 5) 2094
# CPRI 87
# drop ratio           NaN
# pb                  0.83
# roe               14.20%
# market cap         2.22B
# price on 04-09       NaN
# Debt/Eq             0.81
# Dividend %             -
# Name: CPRI, dtype: object
# CAH (2588, 5) 2588
# CAH 88
# drop ratio             NaN
# pb                   14.82
# roe               -116.50%
# market cap          14.80B
# price on 04-09         NaN
# Debt/Eq               7.94
# Dividend %           3.79%
# Name: CAH, dtype: object
# KMX (2587, 5) 2587
# KMX 89
# drop ratio        0.633356
# pb                    2.86
# roe                 25.00%
# market cap          10.58B
# price on 04-09        66.5
# Debt/Eq               4.08
# Dividend %               -
# Name: KMX, dtype: object
# CCL (2587, 5) 2587
# CCL 90
# drop ratio        0.220257
# pb                    0.35
# roe                  7.60%
# market cap           8.96B
# price on 04-09       12.42
# Debt/Eq               0.53
# Dividend %               -
# Name: CCL, dtype: object
# CARR (18, 5) 18
# CARR 91
# drop ratio           NaN
# pb                     -
# roe                    -
# market cap        12.01B
# price on 04-09       NaN
# Debt/Eq                -
# Dividend %             -
# Name: CARR, dtype: object
# CAT (2588, 5) 2588
# CAT 92
# drop ratio           NaN
# pb                  4.40
# roe               40.70%
# market cap        66.77B
# price on 04-09       NaN
# Debt/Eq             2.58
# Dividend %         3.54%
# Name: CAT, dtype: object
# CBOE (2475, 5) 2475
# CBOE 93
# drop ratio           NaN
# pb                  3.58
# roe                    -
# market cap        11.03B
# price on 04-09       NaN
# Debt/Eq                -
# Dividend %         1.43%
# Name: CBOE, dtype: object
# CBRE (2587, 5) 2587
# CBRE 94
# drop ratio        0.654391
# pb                    2.36
# roe                 23.10%
# market cap          14.63B
# price on 04-09       45.61
# Debt/Eq               0.46
# Dividend %               -
# Name: CBRE, dtype: object
# CDW (1711, 5) 1711
# CDW 95
# drop ratio           NaN
# pb                 15.93
# roe               78.40%
# market cap        15.30B
# price on 04-09       NaN
# Debt/Eq             3.32
# Dividend %         1.42%
# Name: CDW, dtype: object
# CE (2587, 5) 2587
# CE 96
# drop ratio        0.602936
# pb                    3.90
# roe                 30.50%
# market cap           9.78B
# price on 04-09       83.91
# Debt/Eq               1.56
# Dividend %           3.05%
# Name: CE, dtype: object
# CNC (2587, 5) 2587
# CNC 97
# drop ratio        0.942672
# pb                    2.19
# roe                 10.90%
# market cap          38.22B
# price on 04-09       66.42
# Debt/Eq               1.09
# Dividend %               -
# Name: CNC, dtype: object
# CNP (2587, 5) 2587
# CNP 98
# drop ratio        0.577091
# pb                    1.29
# roe                 10.30%
# market cap           8.54B
# price on 04-09       17.81
# Debt/Eq               2.42
# Dividend %           3.53%
# Name: CNP, dtype: object
# CTL (2587, 5) 2587
# CTL 99
# drop ratio        0.722413
# pb                    0.82
# roe                -38.80%
# market cap          10.32B
# price on 04-09       10.65
# Debt/Eq               2.58
# Dividend %           9.75%
# Name: CTL, dtype: object
# CERN (2587, 5) 2587
# CERN 100
# drop ratio        0.86511
# pb                   4.99
# roe                11.40%
# market cap         21.52B
# price on 04-09      68.38
# Debt/Eq              0.24
# Dividend %          1.04%
# Name: CERN, dtype: object
# CF (2587, 5) 2587
# CF 101
# drop ratio        0.578596
# pb                    2.25
# roe                 16.60%
# market cap           6.53B
# price on 04-09       31.01
# Debt/Eq               0.00
# Dividend %           3.99%
# Name: CF, dtype: object
# SCHW (2587, 5) 2587
# SCHW 102
# drop ratio        0.721384
# pb                    2.45
# roe                 18.80%
# market cap          46.55B
# price on 04-09       36.54
# Debt/Eq              12.01
# Dividend %           1.99%
# Name: SCHW, dtype: object
# CHTR (2586, 5) 2586
# CHTR 103
# drop ratio            NaN
# pb                   3.31
# roe                 4.90%
# market cap        113.99B
# price on 04-09        NaN
# Debt/Eq              2.52
# Dividend %              -
# Name: CHTR, dtype: object
# CVX (2587, 5) 2587
# CVX 104
# drop ratio        0.634691
# pb                    1.10
# roe                  1.90%
# market cap         161.09B
# price on 04-09       84.31
# Debt/Eq               0.19
# Dividend %           6.10%
# Name: CVX, dtype: object
# CMG (2587, 5) 2587
# CMG 105
# drop ratio        0.793237
# pb                   12.96
# roe                 22.10%
# market cap          21.81B
# price on 04-09         771
# Debt/Eq               0.00
# Dividend %               -
# Name: CMG, dtype: object
# CB (2587, 5) 2587
# CB 106
# drop ratio        0.712145
# pb                    1.00
# roe                  8.20%
# market cap          55.45B
# price on 04-09      122.27
# Debt/Eq               0.27
# Dividend %           2.45%
# Name: CB, dtype: object
# CHD (2587, 5) 2587
# CHD 107
# drop ratio        0.940557
# pb                    6.64
# roe                 23.80%
# market cap          17.79B
# price on 04-09       68.39
# Debt/Eq               0.77
# Dividend %           1.33%
# Name: CHD, dtype: object
# CI (2587, 5) 2587
# CI 108
# drop ratio        0.851028
# pb                    1.52
# roe                 11.60%
# market cap          70.73B
# price on 04-09      181.83
# Debt/Eq               0.83
# Dividend %           0.02%
# Name: CI, dtype: object
# CINF (2587, 5) 2587
# CINF 109
# drop ratio        0.737024
# pb                    1.44
# roe                 21.60%
# market cap          13.71B
# price on 04-09       83.58
# Debt/Eq               0.09
# Dividend %           2.76%
# Name: CINF, dtype: object
# CTAS (2587, 5) 2587
# CTAS 110
# drop ratio        0.661587
# pb                    6.32
# roe                 31.20%
# market cap          20.32B
# price on 04-09      198.74
# Debt/Eq               0.82
# Dividend %           1.26%
# Name: CTAS, dtype: object
# CSCO (2587, 5) 2587
# CSCO 111
# drop ratio        0.837567
# pb                    5.11
# roe                 31.50%
# market cap         183.80B
# price on 04-09        41.2
# Debt/Eq               0.45
# Dividend %           3.27%
# Name: CSCO, dtype: object
# C (2587, 5) 2587
# C 112
# drop ratio        0.527291
# pb                    0.56
# roe                 10.20%
# market cap          97.63B
# price on 04-09       47.41
# Debt/Eq               1.39
# Dividend %           4.49%
# Name: C, dtype: object
# CFG (1398, 5) 1398
# CFG 113
# drop ratio          NaN
# pb                 0.43
# roe               8.30%
# market cap        8.83B
# price on 04-09      NaN
# Debt/Eq            0.68
# Dividend %        7.67%
# Name: CFG, dtype: object
# CTXS (2587, 5) 2587
# CTXS 114
# drop ratio          1.286
# pb                  22.36
# roe               104.40%
# market cap         18.53B
# price on 04-09      139.4
# Debt/Eq              0.89
# Dividend %          0.97%
# Name: CTXS, dtype: object
# CLX (2587, 5) 2587
# CLX 115
# drop ratio        1.16458
# pb                  43.98
# roe               133.50%
# market cap         24.38B
# price on 04-09     184.21
# Debt/Eq              5.06
# Dividend %          2.18%
# Name: CLX, dtype: object
# CME (2587, 5) 2587
# CME 116
# drop ratio        0.867727
# pb                    2.57
# roe                  8.00%
# market cap          67.23B
# price on 04-09      190.16
# Debt/Eq               0.15
# Dividend %           1.81%
# Name: CME, dtype: object
# CMS (2587, 5) 2587
# CMS 117
# drop ratio        0.937025
# pb                    3.52
# roe                 13.80%
# market cap          17.64B
# price on 04-09       62.33
# Debt/Eq               2.63
# Dividend %           2.62%
# Name: CMS, dtype: object
# KO (2587, 5) 2587
# KO 118
# drop ratio        0.82185
# pb                  11.04
# roe                48.80%
# market cap        209.62B
# price on 04-09         49
# Debt/Eq              2.25
# Dividend %          3.35%
# Name: KO, dtype: object
# CTSH (2587, 5) 2587
# CTSH 119
# drop ratio        0.762024
# pb                    2.68
# roe                 17.00%
# market cap          28.09B
# price on 04-09       54.28
# Debt/Eq               0.07
# Dividend %           1.63%
# Name: CTSH, dtype: object
# CL (2587, 5) 2587
# CL 120
# drop ratio          0.9899
# pb                  522.21
# roe               -856.10%
# market cap          62.97B
# price on 04-09       69.91
# Debt/Eq              67.07
# Dividend %           2.41%
# Name: CL, dtype: object
# CMCSA (2587, 5) 2587
# CMCSA 121
# drop ratio        0.790263
# pb                    2.12
# roe                 16.70%
# market cap         173.91B
# price on 04-09          38
# Debt/Eq               1.30
# Dividend %           2.39%
# Name: CMCSA, dtype: object
# CMA (2587, 5) 2587
# CMA 122
# drop ratio        0.424615
# pb                    0.61
# roe                 16.30%
# market cap           4.45B
# price on 04-09       34.75
# Debt/Eq               0.47
# Dividend %           8.81%
# Name: CMA, dtype: object
# CAG (2588, 5) 2588
# CAG 123
# drop ratio           NaN
# pb                  2.09
# roe               10.10%
# market cap        16.25B
# price on 04-09       NaN
# Debt/Eq             1.29
# Dividend %         2.55%
# Name: CAG, dtype: object
# CXO (2587, 5) 2587
# CXO 124
# drop ratio        0.534252
# pb                    0.57
# roe                 -3.90%
# market cap          10.14B
# price on 04-09       52.74
# Debt/Eq               0.22
# Dividend %           1.56%
# Name: CXO, dtype: object
# COP (2587, 5) 2587
# COP 125
# drop ratio        0.495517
# pb                    1.07
# roe                 21.20%
# market cap          37.70B
# price on 04-09       34.73
# Debt/Eq               0.43
# Dividend %           4.93%
# Name: COP, dtype: object
# ED (2587, 5) 2587
# ED 126
# drop ratio        0.896949
# pb                    1.65
# roe                  7.60%
# market cap          28.43B
# price on 04-09       87.94
# Debt/Eq               1.20
# Dividend %           3.43%
# Name: ED, dtype: object
# STZ (2587, 5) 2587
# STZ 127
# drop ratio        0.768027
# pb                    2.75
# roe                  6.50%
# market cap          30.52B
# price on 04-09      166.24
# Debt/Eq               1.06
# Dividend %           1.79%
# Name: STZ, dtype: object
# COO (2587, 5) 2587
# COO 128
# drop ratio        0.886837
# pb                    3.95
# roe                 12.50%
# market cap          16.07B
# price on 04-09      296.57
# Debt/Eq               0.48
# Dividend %           0.02%
# Name: COO, dtype: object
# CPRT (2587, 5) 2587
# CPRT 129
# drop ratio        0.747641
# pb                    7.79
# roe                 39.40%
# market cap          15.96B
# price on 04-09       74.99
# Debt/Eq               0.19
# Dividend %               -
# Name: CPRT, dtype: object
# GLW (2587, 5) 2587
# GLW 130
# drop ratio        0.682571
# pb                    1.37
# roe                  7.90%
# market cap          15.33B
# price on 04-09       21.18
# Debt/Eq               0.73
# Dividend %           4.25%
# Name: GLW, dtype: object
# CTVA (224, 5) 224
# CTVA 131
# drop ratio           NaN
# pb                  0.82
# roe                    -
# market cap        19.82B
# price on 04-09       NaN
# Debt/Eq             0.01
# Dividend %         1.97%
# Name: CTVA, dtype: object
# COST (2587, 5) 2587
# COST 132
# drop ratio        1.00202
# pb                   8.36
# roe                24.30%
# market cap        141.47B
# price on 04-09     300.01
# Debt/Eq              0.37
# Dividend %          0.83%
# Name: COST, dtype: object
# COTY (1721, 5) 1721
# COTY 133
# drop ratio            NaN
# pb                   1.07
# roe               -52.90%
# market cap          4.67B
# price on 04-09        NaN
# Debt/Eq              1.66
# Dividend %          7.95%
# Name: COTY, dtype: object
# CCI (2587, 5) 2587
# CCI 134
# drop ratio        1.0442
# pb                  6.58
# roe                6.60%
# market cap        68.96B
# price on 04-09    164.14
# Debt/Eq             1.73
# Dividend %         2.90%
# Name: CCI, dtype: object
# CSX (2587, 5) 2587
# CSX 135
# drop ratio        0.810603
# pb                    4.09
# roe                 27.50%
# market cap          48.47B
# price on 04-09          64
# Debt/Eq               1.37
# Dividend %           1.66%
# Name: CSX, dtype: object
# CMI (2587, 5) 2587
# CMI 136
# drop ratio        0.771992
# pb                    2.98
# roe                 28.80%
# market cap          22.40B
# price on 04-09       150.7
# Debt/Eq               0.32
# Dividend %           3.54%
# Name: CMI, dtype: object
# CVS (2587, 5) 2587
# CVS 137
# drop ratio        0.781812
# pb                    1.26
# roe                 10.70%
# market cap          80.27B
# price on 04-09       60.47
# Debt/Eq               1.07
# Dividend %           3.25%
# Name: CVS, dtype: object
# DHI (2587, 5) 2587
# DHI 138
# drop ratio        0.677965
# pb                    1.45
# roe                 18.00%
# market cap          14.21B
# price on 04-09       41.04
# Debt/Eq               0.37
# Dividend %           1.74%
# Name: DHI, dtype: object
# DHR (2587, 5) 2587
# DHR 139
# drop ratio        0.904821
# pb                    3.80
# roe                  9.80%
# market cap         105.59B
# price on 04-09      145.73
# Debt/Eq               0.76
# Dividend %           0.47%
# Name: DHR, dtype: object
# DRI (2587, 5) 2587
# DRI 140
# drop ratio        0.491823
# pb                    3.17
# roe                      -
# market cap           7.42B
# price on 04-09       64.34
# Debt/Eq               0.55
# Dividend %               -
# Name: DRI, dtype: object
# DVA (2587, 5) 2587
# DVA 141
# drop ratio        0.974982
# pb                    4.66
# roe                 26.20%
# market cap           9.92B
# price on 04-09       74.82
# Debt/Eq               3.80
# Dividend %               -
# Name: DVA, dtype: object
# DE (2587, 5) 2587
# DE 142
# drop ratio        0.800423
# pb                    3.63
# roe                 27.50%
# market cap          43.62B
# price on 04-09      145.75
# Debt/Eq               3.76
# Dividend %           2.20%
# Name: DE, dtype: object
# DAL (2587, 5) 2587
# DAL 143
# drop ratio        0.421474
# pb                    1.03
# roe                 33.30%
# market cap          15.75B
# price on 04-09       24.39
# Debt/Eq               0.73
# Dividend %               -
# Name: DAL, dtype: object
# XRAY (2587, 5) 2587
# XRAY 144
# drop ratio        0.675772
# pb                    1.78
# roe                  5.10%
# market cap           9.04B
# price on 04-09       41.87
# Debt/Eq               0.28
# Dividend %           0.98%
# Name: XRAY, dtype: object
# DVN (2587, 5) 2587
# DVN 145
# drop ratio        0.304079
# pb                    0.59
# roe                 -5.30%
# market cap           3.39B
# price on 04-09        9.67
# Debt/Eq               0.78
# Dividend %           4.83%
# Name: DVN, dtype: object
# FANG (1886, 5) 1886
# FANG 146
# drop ratio          NaN
# pb                 0.39
# roe               1.70%
# market cap        5.39B
# price on 04-09      NaN
# Debt/Eq            0.41
# Dividend %        4.74%
# Name: FANG, dtype: object
# DLR (2587, 5) 2587
# DLR 147
# drop ratio        1.17685
# pb                   3.58
# roe                 5.80%
# market cap         36.94B
# price on 04-09     148.29
# Debt/Eq              1.22
# Dividend %          2.98%
# Name: DLR, dtype: object
# DFS (2587, 5) 2587
# DFS 148
# drop ratio        0.409584
# pb                    0.98
# roe                 26.40%
# market cap          11.05B
# price on 04-09       39.21
# Debt/Eq               2.28
# Dividend %           4.95%
# Name: DFS, dtype: object
# DISCA (2587, 5) 2587
# DISCA 149
# drop ratio        0.609144
# pb                    1.19
# roe                 16.20%
# market cap          11.80B
# price on 04-09       22.32
# Debt/Eq               1.58
# Dividend %               -
# Name: DISCA, dtype: object
# DISCK (2587, 5) 2587
# DISCK 150
# drop ratio        0.591981
# pb                    1.42
# roe                      -
# market cap               -
# price on 04-09       20.14
# Debt/Eq                  -
# Dividend %               -
# Name: DISCK, dtype: object
# DISH (2587, 5) 2587
# DISH 151
# drop ratio        0.573093
# pb                    0.96
# roe                 14.00%
# market cap          11.02B
# price on 04-09       23.07
# Debt/Eq               1.22
# Dividend %               -
# Name: DISH, dtype: object
# DG (2587, 5) 2587
# DG 152
# drop ratio        1.02332
# pb                   6.73
# roe                25.70%
# market cap         44.78B
# price on 04-09     169.24
# Debt/Eq              0.43
# Dividend %          0.81%
# Name: DG, dtype: object
# DLTR (2587, 5) 2587
# DLTR 153
# drop ratio        0.808247
# pb                    3.02
# roe                 13.80%
# market cap          19.32B
# price on 04-09       77.56
# Debt/Eq               0.60
# Dividend %               -
# Name: DLTR, dtype: object
# D (2587, 5) 2587
# D 154
# drop ratio        0.902865
# pb                    2.29
# roe                  4.90%
# market cap          65.92B
# price on 04-09       81.59
# Debt/Eq               1.28
# Dividend %           4.58%
# Name: D, dtype: object
# DOV (2587, 5) 2587
# DOV 155
# drop ratio        0.725342
# pb                    4.19
# roe                 22.90%
# market cap          12.66B
# price on 04-09       89.41
# Debt/Eq               1.02
# Dividend %           2.23%
# Name: DOV, dtype: object
# DOW (270, 5) 270
# DOW 156
# drop ratio           NaN
# pb                  1.95
# roe               -7.20%
# market cap        26.37B
# price on 04-09       NaN
# Debt/Eq             1.26
# Dividend %         7.92%
# Name: DOW, dtype: object
# DTE (2587, 5) 2587
# DTE 157
# drop ratio        0.748099
# pb                    1.77
# roe                 10.80%
# market cap          19.47B
# price on 04-09      111.25
# Debt/Eq               1.50
# Dividend %           3.74%
# Name: DTE, dtype: object
# DUK (2587, 5) 2587
# DUK 158
# drop ratio        0.899265
# pb                    1.48
# roe                  8.30%
# market cap          62.84B
# price on 04-09       90.31
# Debt/Eq               1.37
# Dividend %           4.18%
# Name: DUK, dtype: object
# DRE (2587, 5) 2587
# DRE 159
# drop ratio        0.930289
# pb                    2.61
# roe                  8.90%
# market cap          12.33B
# price on 04-09       35.56
# Debt/Eq               0.58
# Dividend %           2.64%
# Name: DRE, dtype: object
# DD (2587, 5) 2587
# DD 160
# drop ratio        0.55446
# pb                   0.69
# roe                 0.80%
# market cap         28.46B
# price on 04-09      40.78
# Debt/Eq              0.43
# Dividend %          3.12%
# Name: DD, dtype: object
# DXC (2587, 5) 2587
# DXC 161
# drop ratio        0.372897
# pb                    0.45
# roe                -16.20%
# market cap           3.92B
# price on 04-09       16.09
# Debt/Eq               1.02
# Dividend %           5.46%
# Name: DXC, dtype: object
# ETFC (2587, 5) 2587
# ETFC 162
# drop ratio        0.790338
# pb                    1.55
# roe                 15.20%
# market cap           9.10B
# price on 04-09       41.76
# Debt/Eq               6.84
# Dividend %           1.38%
# Name: ETFC, dtype: object
# EMN (2587, 5) 2587
# EMN 163
# drop ratio        0.634641
# pb                    1.29
# roe                 12.80%
# market cap           7.66B
# price on 04-09       59.71
# Debt/Eq               0.97
# Dividend %           4.68%
# Name: EMN, dtype: object
# ETN (2587, 5) 2587
# ETN 164
# drop ratio        0.803812
# pb                    2.06
# roe                 13.70%
# market cap          33.05B
# price on 04-09       81.44
# Debt/Eq               0.52
# Dividend %           3.66%
# Name: ETN, dtype: object
# EBAY (2587, 5) 2587
# EBAY 165
# drop ratio        0.854716
# pb                   10.04
# roe                 46.20%
# market cap          27.76B
# price on 04-09       33.83
# Debt/Eq               2.70
# Dividend %           1.79%
# Name: EBAY, dtype: object
# ECL (2587, 5) 2587
# ECL 166
# drop ratio        0.831387
# pb                    6.00
# roe                 18.50%
# market cap          52.14B
# price on 04-09      179.86
# Debt/Eq               0.73
# Dividend %           1.04%
# Name: ECL, dtype: object
# EIX (2587, 5) 2587
# EIX 167
# drop ratio        0.725073
# pb                    1.62
# roe                 10.80%
# market cap          20.73B
# price on 04-09       60.27
# Debt/Eq               1.42
# Dividend %           4.26%
# Name: EIX, dtype: object
# EW (2587, 5) 2587
# EW 168
# drop ratio        0.828324
# pb                   10.88
# roe                 28.10%
# market cap          45.16B
# price on 04-09      215.44
# Debt/Eq               0.00
# Dividend %               -
# Name: EW, dtype: object
# EA (2587, 5) 2587
# EA 169
# drop ratio        0.946543
# pb                    4.52
# roe                 43.20%
# market cap          32.76B
# price on 04-09       105.8
# Debt/Eq               0.14
# Dividend %               -
# Name: EA, dtype: object
# EMR (2587, 5) 2587
# EMR 170
# drop ratio        0.629995
# pb                    3.66
# roe                 25.50%
# market cap          31.08B
# price on 04-09       51.78
# Debt/Eq               0.71
# Dividend %           3.96%
# Name: EMR, dtype: object
# ETR (2587, 5) 2587
# ETR 171
# drop ratio        0.787136
# pb                    1.96
# roe                 12.70%
# market cap          19.74B
# price on 04-09      102.91
# Debt/Eq               1.95
# Dividend %           3.70%
# Name: ETR, dtype: object
# EOG (2588, 5) 2588
# EOG 172
# drop ratio           NaN
# pb                  1.13
# roe               13.10%
# market cap        24.84B
# price on 04-09       NaN
# Debt/Eq             0.24
# Dividend %         3.55%
# Name: EOG, dtype: object
# EFX (2587, 5) 2587
# EFX 173
# drop ratio        0.83051
# pb                   6.10
# roe               -15.60%
# market cap         15.63B
# price on 04-09     124.22
# Debt/Eq              1.31
# Dividend %          1.20%
# Name: EFX, dtype: object
# EQIX (2587, 5) 2587
# EQIX 174
# drop ratio        1.09307
# pb                   6.65
# roe                 5.80%
# market cap         58.76B
# price on 04-09     686.94
# Debt/Eq              1.34
# Dividend %          1.54%
# Name: EQIX, dtype: object
# EQR (2587, 5) 2587
# EQR 175
# drop ratio        0.756312
# pb                    2.49
# roe                  9.50%
# market cap          25.58B
# price on 04-09       69.42
# Debt/Eq               0.88
# Dividend %           3.50%
# Name: EQR, dtype: object
# ESS (2587, 5) 2587
# ESS 176
# drop ratio        0.724699
# pb                    2.68
# roe                  7.10%
# market cap          16.70B
# price on 04-09      246.96
# Debt/Eq               0.93
# Dividend %           3.29%
# Name: ESS, dtype: object
# EL (2587, 5) 2587
# EL 177
# drop ratio        0.773055
# pb                   12.99
# roe                 41.20%
# market cap          59.65B
# price on 04-09      164.83
# Debt/Eq               1.13
# Dividend %           1.16%
# Name: EL, dtype: object
# EVRG (2587, 5) 2587
# EVRG 178
# drop ratio        0.887144
# pb                    1.66
# roe                  7.50%
# market cap          14.23B
# price on 04-09        63.1
# Debt/Eq               1.17
# Dividend %           3.04%
# Name: EVRG, dtype: object
# ES (2587, 5) 2587
# ES 179
# drop ratio        0.962728
# pb                    2.35
# roe                  7.50%
# market cap          27.93B
# price on 04-09        90.1
# Debt/Eq               1.23
# Dividend %           2.48%
# Name: ES, dtype: object
# RE (2587, 5) 2587
# RE 180
# drop ratio        0.69454
# pb                   0.90
# roe                11.30%
# market cap          7.72B
# price on 04-09      212.3
# Debt/Eq              0.07
# Dividend %          3.05%
# Name: RE, dtype: object
# EXC (2587, 5) 2587
# EXC 181
# drop ratio        0.79087
# pb                   1.18
# roe                 9.20%
# market cap         38.13B
# price on 04-09      39.15
# Debt/Eq              1.17
# Dividend %          3.92%
# Name: EXC, dtype: object
# EXPE (2587, 5) 2587
# EXPE 182
# drop ratio        0.508329
# pb                    2.24
# roe                 13.60%
# market cap           8.36B
# price on 04-09       62.42
# Debt/Eq               1.24
# Dividend %           2.21%
# Name: EXPE, dtype: object
# EXPD (2587, 5) 2587
# EXPD 183
# drop ratio        0.881893
# pb                    5.48
# roe                 27.50%
# market cap          12.03B
# price on 04-09       71.48
# Debt/Eq               0.00
# Dividend %           1.42%
# Name: EXPD, dtype: object
# EXR (2587, 5) 2587
# EXR 184
# drop ratio        0.927246
# pb                    4.87
# roe                 17.00%
# market cap          12.37B
# price on 04-09      102.91
# Debt/Eq               1.99
# Dividend %           3.76%
# Name: EXR, dtype: object
# XOM (2587, 5) 2587
# XOM 185
# drop ratio        0.567607
# pb                    0.95
# roe                  7.50%
# market cap         182.57B
# price on 04-09       43.13
# Debt/Eq               0.25
# Dividend %           8.20%
# Name: XOM, dtype: object
# FFIV (2587, 5) 2587
# FFIV 186
# drop ratio        0.805323
# pb                    3.87
# roe                 23.30%
# market cap           7.46B
# price on 04-09      125.39
# Debt/Eq               0.00
# Dividend %               -
# Name: FFIV, dtype: object
# FB (1988, 5) 1988
# FB 187
# drop ratio            NaN
# pb                   5.03
# roe                20.00%
# market cap        505.23B
# price on 04-09        NaN
# Debt/Eq              0.00
# Dividend %              -
# Name: FB, dtype: object
# FAST (2587, 5) 2587
# FAST 188
# drop ratio        0.857464
# pb                    7.41
# roe                 31.20%
# market cap          19.77B
# price on 04-09       33.62
# Debt/Eq               0.13
# Dividend %           2.90%
# Name: FAST, dtype: object
# FRT (2587, 5) 2587
# FRT 189
# drop ratio        0.582558
# pb                    2.68
# roe                 15.10%
# market cap           6.37B
# price on 04-09          86
# Debt/Eq               1.44
# Dividend %           4.96%
# Name: FRT, dtype: object
# FDX (2587, 5) 2587
# FDX 190
# drop ratio        0.782521
# pb                    1.73
# roe                 -1.90%
# market cap          33.55B
# price on 04-09      122.29
# Debt/Eq               1.03
# Dividend %           2.08%
# Name: FDX, dtype: object
# FIS (2587, 5) 2587
# FIS 191
# drop ratio        0.868136
# pb                    1.54
# roe                  1.00%
# market cap          76.08B
# price on 04-09      125.12
# Debt/Eq               0.41
# Dividend %           1.13%
# Name: FIS, dtype: object
# FITB (2587, 5) 2587
# FITB 192
# drop ratio        0.502857
# pb                    0.63
# roe                 12.50%
# market cap          12.24B
# price on 04-09       17.82
# Debt/Eq               0.77
# Dividend %           6.30%
# Name: FITB, dtype: object
# FE (2587, 5) 2587
# FE 193
# drop ratio        0.841483
# pb                    3.53
# roe                 12.80%
# market cap          24.60B
# price on 04-09       44.75
# Debt/Eq               3.01
# Dividend %           3.43%
# Name: FE, dtype: object
# FRC (2351, 5) 2351
# FRC 194
# drop ratio           NaN
# pb                  1.97
# roe               10.20%
# market cap        16.01B
# price on 04-09       NaN
# Debt/Eq             0.15
# Dividend %         0.76%
# Name: FRC, dtype: object
# FISV (2587, 5) 2587
# FISV 195
# drop ratio        0.80702
# pb                   2.00
# roe                 5.10%
# market cap         64.94B
# price on 04-09      99.22
# Debt/Eq              0.66
# Dividend %              -
# Name: FISV, dtype: object
# FLT (2347, 5) 2347
# FLT 196
# drop ratio           NaN
# pb                  5.18
# roe               23.90%
# market cap        19.21B
# price on 04-09       NaN
# Debt/Eq             1.36
# Dividend %             -
# Name: FLT, dtype: object
# FLIR (2587, 5) 2587
# FLIR 197
# drop ratio        0.628202
# pb                    2.50
# roe                  9.10%
# market cap           4.74B
# price on 04-09        34.5
# Debt/Eq               0.36
# Dividend %           1.95%
# Name: FLIR, dtype: object
# FLS (2587, 5) 2587
# FLS 198
# drop ratio        0.496226
# pb                    1.87
# roe                 14.60%
# market cap           3.55B
# price on 04-09       27.19
# Debt/Eq               0.77
# Dividend %           3.12%
# Name: FLS, dtype: object
# FMC (2587, 5) 2587
# FMC 199
# drop ratio        0.793836
# pb                    4.44
# roe                 17.80%
# market cap          11.24B
# price on 04-09          90
# Debt/Eq               1.29
# Dividend %           2.03%
# Name: FMC, dtype: object
# F (2587, 5) 2587
# F 200
# drop ratio        0.509835
# pb                    0.63
# roe                  0.10%
# market cap          20.95B
# price on 04-09        5.37
# Debt/Eq               4.68
# Dividend %               -
# Name: F, dtype: object
# FTNT (2587, 5) 2587
# FTNT 201
# drop ratio        0.947548
# pb                   14.16
# roe                 27.80%
# market cap          20.21B
# price on 04-09      101.93
# Debt/Eq               0.00
# Dividend %               -
# Name: FTNT, dtype: object
# FTV (951, 5) 951
# FTV 202
# drop ratio           NaN
# pb                  2.78
# roe                9.40%
# market cap        20.39B
# price on 04-09       NaN
# Debt/Eq             0.86
# Dividend %         0.46%
# Name: FTV, dtype: object
# FBHS (2157, 5) 2157
# FBHS 203
# drop ratio           NaN
# pb                  2.66
# roe               18.50%
# market cap         6.44B
# price on 04-09       NaN
# Debt/Eq             0.90
# Dividend %         2.08%
# Name: FBHS, dtype: object
# FOXA (276, 5) 276
# ...
# pb                   1.28
# roe                17.40%
# market cap          4.24B
# price on 04-09       15.7
# Debt/Eq              0.48
# Dividend %              -
# Name: TPR, dtype: object
# TGT (2587, 5) 2587
# TGT 439
# drop ratio        0.760804
# pb                    4.64
# roe                 28.30%
# market cap          54.52B
# price on 04-09       104.2
# Debt/Eq               0.97
# Dividend %           2.44%
# Name: TGT, dtype: object
# TEL (2587, 5) 2587
# TEL 440
# drop ratio        0.667173
# pb                    2.22
# roe                 15.30%
# market cap          23.44B
# price on 04-09       71.17
# Debt/Eq               0.38
# Dividend %           2.63%
# Name: TEL, dtype: object
# FTI (2587, 5) 2587
# FTI 441
# drop ratio        0.35319
# pb                   0.49
# roe               -25.10%
# market cap          3.97B
# price on 04-09        8.4
# Debt/Eq              0.58
# Dividend %          6.15%
# Name: FTI, dtype: object
# TFX (2587, 5) 2587
# TFX 442
# drop ratio        0.803612
# pb                    5.15
# roe                 16.70%
# market cap          15.33B
# price on 04-09      325.56
# Debt/Eq               0.64
# Dividend %           0.41%
# Name: TFX, dtype: object
# TXN (2588, 5) 2588
# TXN 443
# drop ratio            NaN
# pb                  11.62
# roe                57.20%
# market cap        105.98B
# price on 04-09        NaN
# Debt/Eq              0.65
# Dividend %          3.24%
# Name: TXN, dtype: object
# TXT (2587, 5) 2587
# TXT 444
# drop ratio        0.593198
# pb                    1.14
# roe                 15.10%
# market cap           6.28B
# price on 04-09       29.44
# Debt/Eq               0.69
# Dividend %           0.29%
# Name: TXT, dtype: object
# TMO (2587, 5) 2587
# TMO 445
# drop ratio        0.894161
# pb                    4.40
# roe                 12.80%
# market cap         130.55B
# price on 04-09      317.38
# Debt/Eq               0.60
# Dividend %           0.27%
# Name: TMO, dtype: object
# TIF (2587, 5) 2587
# TIF 446
# drop ratio        0.962782
# pb                    4.72
# roe                 16.90%
# market cap          15.83B
# price on 04-09      127.95
# Debt/Eq               0.31
# Dividend %           1.80%
# Name: TIF, dtype: object
# TJX (2587, 5) 2587
# TJX 447
# drop ratio        0.759177
# pb                   10.15
# roe                 59.70%
# market cap          60.52B
# price on 04-09       48.81
# Debt/Eq               0.38
# Dividend %           1.83%
# Name: TJX, dtype: object
# TSCO (2587, 5) 2587
# TSCO 448
# drop ratio        0.922784
# pb                    7.02
# roe                 36.90%
# market cap          11.09B
# price on 04-09       88.23
# Debt/Eq               0.27
# Dividend %           1.51%
# Name: TSCO, dtype: object
# TT (2298, 5) 2298
# TT 449
# HTTP Error 404: Not Found
# An exception occurred
# TDG (2587, 5) 2587
# TDG 450
# drop ratio        0.535577
# pb                       -
# roe                      -
# market cap          18.26B
# price on 04-09      344.54
# Debt/Eq                  -
# Dividend %               -
# Name: TDG, dtype: object
# TRV (2587, 5) 2587
# TRV 451
# drop ratio        0.733588
# pb                    1.07
# roe                 10.30%
# market cap          27.73B
# price on 04-09      109.74
# Debt/Eq               0.25
# Dividend %           3.04%
# Name: TRV, dtype: object
# TFC (2587, 5) 2587
# TFC 452
# drop ratio        0.550426
# pb                    0.50
# roe                  8.20%
# market cap          40.63B
# price on 04-09       36.11
# Debt/Eq               0.61
# Dividend %           5.40%
# Name: TFC, dtype: object
# TWTR (1618, 5) 1618
# TWTR 453
# drop ratio           NaN
# pb                  2.49
# roe               18.00%
# market cap        21.93B
# price on 04-09       NaN
# Debt/Eq             0.29
# Dividend %             -
# Name: TWTR, dtype: object
# TSN (2587, 5) 2587
# TSN 454
# drop ratio        0.629916
# pb                    1.55
# roe                 14.50%
# market cap          21.49B
# price on 04-09       60.94
# Debt/Eq               0.81
# Dividend %           2.74%
# Name: TSN, dtype: object
# UDR (2587, 5) 2587
# UDR 455
# drop ratio        0.777053
# pb                    3.48
# roe                  5.90%
# market cap          11.54B
# price on 04-09       41.12
# Debt/Eq               1.42
# Dividend %           3.66%
# Name: UDR, dtype: object
# ULTA (2587, 5) 2587
# ULTA 456
# drop ratio        0.709625
# pb                    6.14
# roe                 37.50%
# market cap          11.43B
# price on 04-09      202.48
# Debt/Eq               0.00
# Dividend %               -
# Name: ULTA, dtype: object
# USB (2587, 5) 2587
# USB 457
# drop ratio        0.580991
# pb                    1.22
# roe                 14.10%
# market cap          55.74B
# price on 04-09       38.05
# Debt/Eq               0.85
# Dividend %           4.69%
# Name: USB, dtype: object
# UAA (2587, 5) 2587
# UAA 458
# drop ratio        0.42431
# pb                   2.10
# roe                 4.40%
# market cap          3.98B
# price on 04-09      10.43
# Debt/Eq              0.28
# Dividend %              -
# Name: UAA, dtype: object
# UA (1200, 5) 1200
# UA 459
# drop ratio         NaN
# pb                1.97
# roe                  -
# market cap           -
# price on 04-09     NaN
# Debt/Eq              -
# Dividend %           -
# Name: UA, dtype: object
# UNP (2587, 5) 2587
# UNP 460
# drop ratio        0.79151
# pb                   5.69
# roe                32.90%
# market cap        101.69B
# price on 04-09     148.73
# Debt/Eq              1.39
# Dividend %          2.60%
# Name: UNP, dtype: object
# UAL (2587, 5) 2587
# UAL 461
# drop ratio        0.308967
# pb                    0.68
# roe                 28.00%
# market cap           7.79B
# price on 04-09        31.5
# Debt/Eq               1.29
# Dividend %               -
# Name: UAL, dtype: object
# UNH (2587, 5) 2587
# UNH 462
# drop ratio        0.844457
# pb                    4.45
# roe                 25.50%
# market cap         260.18B
# price on 04-09      264.13
# Debt/Eq               0.71
# Dividend %           1.60%
# Name: UNH, dtype: object
# UPS (2587, 5) 2587
# UPS 463
# drop ratio        0.806457
# pb                   26.75
# roe                106.40%
# market cap          87.14B
# price on 04-09       98.69
# Debt/Eq               7.73
# Dividend %           3.98%
# Name: UPS, dtype: object
# URI (2587, 5) 2587
# URI 464
# drop ratio        0.5971
# pb                  2.13
# roe               32.80%
# market cap         8.34B
# price on 04-09    107.71
# Debt/Eq             2.98
# Dividend %             -
# Name: URI, dtype: object
# UHS (2587, 5) 2587
# UHS 465
# drop ratio        0.669017
# pb                    1.70
# roe                 14.90%
# market cap           9.55B
# price on 04-09      104.51
# Debt/Eq               0.72
# Dividend %           0.74%
# Name: UHS, dtype: object
# UNM (2587, 5) 2587
# UNM 466
# drop ratio        0.500206
# pb                    0.34
# roe                 11.50%
# market cap           3.37B
# price on 04-09       15.58
# Debt/Eq               0.33
# Dividend %           6.97%
# Name: UNM, dtype: object
# VFC (2587, 5) 2587
# VFC 467
# drop ratio        0.550856
# pb                    5.16
# roe                 29.30%
# market cap          23.03B
# price on 04-09       59.21
# Debt/Eq               0.48
# Dividend %           3.22%
# Name: VFC, dtype: object
# VLO (2587, 5) 2587
# VLO 468
# drop ratio        0.486428
# pb                    0.95
# roe                 11.30%
# market cap          21.44B
# price on 04-09        50.1
# Debt/Eq               0.44
# Dividend %           7.69%
# Name: VLO, dtype: object
# VAR (2587, 5) 2587
# VAR 469
# drop ratio        0.723575
# pb                    5.55
# roe                 15.60%
# market cap          10.41B
# price on 04-09      113.15
# Debt/Eq               0.29
# Dividend %               -
# Name: VAR, dtype: object
# VTR (2587, 5) 2587
# VTR 470
# drop ratio        0.472745
# pb                    1.15
# roe                  4.00%
# market cap          12.37B
# price on 04-09        33.8
# Debt/Eq               1.13
# Dividend %           9.55%
# Name: VTR, dtype: object
# VRSN (2587, 5) 2587
# VRSN 471
# drop ratio        0.952746
# pb                       -
# roe                -42.40%
# market cap          23.94B
# price on 04-09      196.07
# Debt/Eq                  -
# Dividend %               -
# Name: VRSN, dtype: object
# VRSK (2587, 5) 2587
# VRSK 472
# drop ratio        0.96129
# pb                  10.85
# roe                20.70%
# market cap         24.49B
# price on 04-09     148.26
# Debt/Eq              1.39
# Dividend %          0.72%
# Name: VRSK, dtype: object
# VZ (2587, 5) 2587
# VZ 473
# drop ratio        0.90384
# pb                   3.92
# roe                33.10%
# market cap        242.21B
# price on 04-09      57.44
# Debt/Eq              1.82
# Dividend %          4.23%
# Name: VZ, dtype: object
# VRTX (2587, 5) 2587
# VRTX 474
# drop ratio        1.08651
# pb                  11.13
# roe                22.30%
# market cap         68.88B
# price on 04-09     246.61
# Debt/Eq              0.09
# Dividend %              -
# Name: VRTX, dtype: object
# VIAC (202, 5) 202
# VIAC 475
# drop ratio           NaN
# pb                  1.65
# roe               48.40%
# market cap         9.70B
# price on 04-09       NaN
# Debt/Eq             1.42
# Dividend %         5.90%
# Name: VIAC, dtype: object
# V (2587, 5) 2587
# V 476
# drop ratio        0.867726
# pb                   12.64
# roe                 40.70%
# market cap         377.84B
# price on 04-09      173.69
# Debt/Eq               0.56
# Dividend %           0.69%
# Name: V, dtype: object
# VNO (2587, 5) 2587
# VNO 477
# drop ratio        0.545916
# pb                    1.45
# roe                 57.50%
# market cap           7.87B
# price on 04-09       43.48
# Debt/Eq               1.27
# Dividend %           5.97%
# Name: VNO, dtype: object
# VMC (2587, 5) 2587
# VMC 478
# drop ratio        0.743544
# pb                    2.65
# roe                 11.40%
# market cap          14.89B
# price on 04-09       113.1
# Debt/Eq               0.50
# Dividend %           1.21%
# Name: VMC, dtype: object
# WRB (2587, 5) 2587
# WRB 479
# drop ratio        0.77099
# pb                   1.85
# roe                11.40%
# market cap         10.19B
# price on 04-09      58.32
# Debt/Eq              0.43
# Dividend %          0.75%
# Name: WRB, dtype: object
# WAB (2587, 5) 2587
# WAB 480
# drop ratio        0.618558
# pb                    1.01
# roe                  3.30%
# market cap           9.47B
# price on 04-09       55.26
# Debt/Eq               0.44
# Dividend %           0.92%
# Name: WAB, dtype: object
# WMT (2587, 5) 2587
# WMT 481
# drop ratio        0.993029
# pb                    4.90
# roe                 20.90%
# market cap         365.48B
# price on 04-09       121.8
# Debt/Eq               0.73
# Dividend %           1.67%
# Name: WMT, dtype: object
# WBA (2587, 5) 2587
# WBA 482
# drop ratio        0.732767
# pb                    1.73
# roe                 14.70%
# market cap          39.86B
# price on 04-09       43.98
# Debt/Eq               0.75
# Dividend %           3.95%
# Name: WBA, dtype: object
# DIS (2587, 5) 2587
# DIS 483
# drop ratio        0.675996
# pb                    2.13
# roe                 11.60%
# market cap         191.38B
# price on 04-09       104.5
# Debt/Eq               0.54
# Dividend %           1.66%
# Name: DIS, dtype: object
# WM (2587, 5) 2587
# WM 484
# drop ratio        0.815874
# pb                    5.98
# roe                 25.00%
# market cap          42.30B
# price on 04-09       99.85
# Debt/Eq               1.91
# Dividend %           2.06%
# Name: WM, dtype: object
# WAT (2587, 5) 2587
# WAT 485
# drop ratio        0.805272
# pb                       -
# roe                166.40%
# market cap          12.00B
# price on 04-09      195.93
# Debt/Eq                  -
# Dividend %               -
# Name: WAT, dtype: object
# WEC (2587, 5) 2587
# WEC 486
# drop ratio        0.975698
# pb                    3.10
# roe                 11.30%
# market cap          31.33B
# price on 04-09       98.22
# Debt/Eq               1.26
# Dividend %           2.55%
# Name: WEC, dtype: object
# WFC (2587, 5) 2587
# WFC 487
# drop ratio        0.539966
# pb                    0.76
# roe                 10.40%
# market cap         126.61B
# price on 04-09        33.2
# Debt/Eq               1.38
# Dividend %           6.76%
# Name: WFC, dtype: object
# WELL (2587, 5) 2587
# WELL 488
# drop ratio        0.56177
# pb                   1.39
# roe                 8.10%
# market cap         19.96B
# price on 04-09       56.6
# Debt/Eq              0.97
# Dividend %          6.52%
# Name: WELL, dtype: object
# WDC (2587, 5) 2587
# WDC 489
# drop ratio        0.664985
# pb                    1.42
# roe                -12.20%
# market cap          13.47B
# price on 04-09       45.05
# Debt/Eq               1.05
# Dividend %           4.47%
# Name: WDC, dtype: object
# WU (2587, 5) 2587
# WU 490
# drop ratio        0.70709
# pb                      -
# roe                     -
# market cap          8.31B
# price on 04-09      20.19
# Debt/Eq                 -
# Dividend %          4.46%
# Name: WU, dtype: object
# WRK (1210, 5) 1210
# WRK 491
# drop ratio          NaN
# pb                 0.70
# roe               7.30%
# market cap        8.24B
# price on 04-09      NaN
# Debt/Eq            0.86
# Dividend %        5.83%
# Name: WRK, dtype: object
# WY (2587, 5) 2587
# WY 492
# drop ratio        0.580533
# pb                    1.85
# roe                 -0.90%
# market cap          15.16B
# price on 04-09       21.01
# Debt/Eq               0.78
# Dividend %           6.69%
# Name: WY, dtype: object
# WHR (2587, 5) 2587
# WHR 493
# drop ratio        0.610731
# pb                    2.05
# roe                 40.20%
# market cap           6.56B
# price on 04-09      104.75
# Debt/Eq               1.56
# Dividend %           4.64%
# Name: WHR, dtype: object
# WMB (2587, 5) 2587
# WMB 494
# drop ratio        0.607143
# pb                    1.58
# roe                  6.10%
# market cap          20.99B
# price on 04-09       16.59
# Debt/Eq               1.67
# Dividend %           9.24%
# Name: WMB, dtype: object
# WLTW (2587, 5) 2587
# WLTW 495
# drop ratio        0.848313
# pb                    2.50
# roe                 10.40%
# market cap          25.61B
# price on 04-09      196.02
# Debt/Eq               0.55
# Dividend %           1.38%
# Name: WLTW, dtype: object
# WYNN (2587, 5) 2587
# WYNN 496
# drop ratio        0.425573
# pb                    4.56
# roe                  6.30%
# market cap           7.83B
# price on 04-09       70.65
# Debt/Eq               5.98
# Dividend %           5.37%
# Name: WYNN, dtype: object
# XEL (2587, 5) 2587
# XEL 497
# drop ratio        0.963625
# pb                    2.63
# roe                 10.70%
# market cap          34.78B
# price on 04-09       66.27
# Debt/Eq               1.42
# Dividend %           2.45%
# Name: XEL, dtype: object
# XRX (2587, 5) 2587
# XRX 498
# drop ratio        0.495986
# pb                    0.73
# roe                 26.20%
# market cap           4.02B
# price on 04-09       19.36
# Debt/Eq               0.77
# Dividend %           5.26%
# Name: XRX, dtype: object
# XLNX (2587, 5) 2587
# XLNX 499
# drop ratio        0.81515
# pb                   8.15
# roe                32.40%
# market cap         21.74B
# price on 04-09      83.11
# Debt/Eq              0.00
# Dividend %          1.72%
# Name: XLNX, dtype: object
# XYL (2138, 5) 2138
# XYL 500
# drop ratio           NaN
# pb                  4.29
# roe               13.90%
# market cap        12.62B
# price on 04-09       NaN
# Debt/Eq             0.78
# Dividend %         1.48%
# Name: XYL, dtype: object
# YUM (2587, 5) 2587
# YUM 501
# drop ratio        0.694267
# pb                       -
# roe                -16.20%
# market cap          24.21B
# price on 04-09       80.37
# Debt/Eq                  -
# Dividend %           2.35%
# Name: YUM, dtype: object
# ZBRA (2587, 5) 2587
# ZBRA 502
# drop ratio        0.730381
# pb                    6.07
# roe                 33.20%
# market cap          11.17B
# price on 04-09      201.22
# Debt/Eq               0.69
# Dividend %               -
# Name: ZBRA, dtype: object
# ZBH (2587, 5) 2587
# ZBH 503
# drop ratio        0.661359
# pb                    1.89
# roe                  9.50%
# market cap          23.67B
# price on 04-09      110.36
# Debt/Eq               0.66
# Dividend %           0.85%
# Name: ZBH, dtype: object
# ZION (2587, 5) 2587
# ZION 504
# drop ratio        0.527838
# pb                    0.73
# roe                 11.20%
# market cap           4.93B
# price on 04-09          31
# Debt/Eq               0.25
# Dividend %           4.60%
# Name: ZION, dtype: object
# ZTS (1812, 5) 1812
# ZTS 505
# drop ratio           NaN
# pb                 22.39
# roe               59.30%
# market cap        60.60B
# price on 04-09       NaN
# Debt/Eq             2.38
# Dividend %         0.63%
# Name: ZTS, dtype: object

# %%
df_new = pd.read_csv('500_analysis.csv',index_col=0)

# %%
print(df_new)
# Out:
#       drop ratio         pb          roe   market cap  price on 04-09  \
# MMM          NaN   ['8.60']   ['45.10%']   ['87.08B']             NaN
# ABT          NaN   ['5.07']   ['11.70%']  ['157.60B']             NaN
# ABBV         NaN      ['-']  ['-95.60%']  ['121.88B']             NaN
# ABMD         NaN   ['6.96']   ['24.70%']    ['7.28B']             NaN
# ACN          NaN   ['7.34']   ['33.80%']  ['113.77B']             NaN
# ...          ...        ...          ...          ...             ...
# YUM          NaN      ['-']  ['-16.20%']   ['24.21B']             NaN
# ZBRA         NaN   ['6.07']   ['33.20%']   ['11.17B']             NaN
# ZBH          NaN   ['1.89']    ['9.50%']   ['23.67B']             NaN
# ZION         NaN   ['0.73']   ['11.20%']    ['4.93B']             NaN
# ZTS          NaN  ['22.39']   ['59.30%']   ['60.60B']             NaN
#
#        Debt/Eq Dividend %
# MMM   ['2.03']  ['3.92%']
# ABT   ['0.58']  ['1.62%']
# ABBV     ['-']  ['5.75%']
# ABMD  ['0.00']      ['-']
# ACN   ['0.00']  ['1.80%']
# ...        ...        ...
# YUM      ['-']  ['2.35%']
# ZBRA  ['0.69']      ['-']
# ZBH   ['0.66']  ['0.85%']
# ZION  ['0.25']  ['4.60%']
# ZTS   ['2.38']  ['0.63%']
#
# [501 rows x 7 columns]
